# %%
from keras.models import Sequential
from keras.layers import Dense,Flatten,Conv2D,MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator

#Data
data='./Weather_2'

#Resize all images
data_generator=ImageDataGenerator(rescale=1./255,validation_split=0.3)
train_gen=data_generator.flow_from_directory(data,target_size=(128,128),batch_size=32,class_mode='categorical',shuffle=True,subset='training')
valid_gen=data_generator.flow_from_directory(data,target_size=(128,128),batch_size=32,class_mode='categorical',shuffle=True,subset='validation')

classes=train_gen.num_classes

#Building CNN
model=Sequential()
model.add(Conv2D(64, (3,3), input_shape=(128,128,3), padding='same', strides=(1,1),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2),trainable=False))

model.add(Conv2D(64, (3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2),trainable=False))

#ANN
model.add(Flatten())
model.add(Dense(32,activation='relu'))
model.add(Dense(classes,activation='softmax'))

#Compiling model
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

#Fit model
model.fit(train_gen,epochs=15,validation_data=valid_gen)

print(model.summary())

model.save('./sys2.keras')
# Out:
# Found 28 images belonging to 4 classes.
# Found 12 images belonging to 4 classes.
# Epoch 1/15
# 1/1 [==============================] - 2s 2s/step - loss: 1.4134 - accuracy: 0.2857 - val_loss: 1.8876 - val_accuracy: 0.2500
# Epoch 2/15
# 1/1 [==============================] - 1s 773ms/step - loss: 1.7513 - accuracy: 0.2500 - val_loss: 2.0265 - val_accuracy: 0.2500
# Epoch 3/15
# 1/1 [==============================] - 1s 1s/step - loss: 1.9866 - accuracy: 0.2500 - val_loss: 1.4569 - val_accuracy: 0.2500
# Epoch 4/15
# 1/1 [==============================] - 1s 1s/step - loss: 1.3852 - accuracy: 0.3571 - val_loss: 1.4040 - val_accuracy: 0.2500
# Epoch 5/15
# 1/1 [==============================] - 1s 885ms/step - loss: 1.2788 - accuracy: 0.2500 - val_loss: 1.3353 - val_accuracy: 0.4167
# Epoch 6/15
# 1/1 [==============================] - 1s 716ms/step - loss: 1.1568 - accuracy: 0.6786 - val_loss: 1.2565 - val_accuracy: 0.5000
# Epoch 7/15
# ...
